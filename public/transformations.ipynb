# %%
import pandas as pd

df = pd.read_csv('gym_data.csv')
df['weight_kg'] = pd.to_numeric(df['weight_kg'], errors='raise')
df.to_csv('gym_data_tableau.csv', index=False, float_format='%.2f', decimal=',', separator=';')
